# %% [markdown]
# ## Project 4:  Solving N-Queens Problem using Genetic Algorithms
#
# #### CSC 180  Intelligent Systems
#
# #### Dr. Haiquan Chen, California State University, Sacramento

# %%
# Insert your name, your id, course title, assignment id, and due date here as comment

'''
CSC 180, Project 4, 18 Nov 2022
Jabari Crenshaw, 219953891
John Kieren, 301144467
'''
# Out:
# '\nCSC 180, Project 4, 18 Nov 2022\nJabari Crenshaw, 219953891\nJohn Kieren, 301144467\n'

# %%
# install deap on colab
# !pip install deap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deap in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.21.6)

# %% [markdown]
# ## Part I: Position-index-based board representation

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

# %%
def create_individual():
    return random.sample(range(64), 8)

# %%
print(create_individual())
# Out:
# [18, 49, 33, 57, 53, 45, 7, 17]

# %%
def show_grid(board):
    
    n = [0]*64
    for i in board:
        n[i] = 1
    
    
    for i in range(8):
        for j in range(64):
            if j // 8 == i:
                if n[j] == 1:
                    print('X',end="|")
                else:
                    print('-',end="|")
        print('')
        print("----------------")

# %%
toolbox = base.Toolbox()

toolbox.register("individual", tools.initIterate, creator.Individual, create_individual)

toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
pop = toolbox.population(n=5)

print(pop[0])
# Out:
# [11, 30, 5, 55, 39, 37, 0, 43]

# %%
show_grid(pop[0])
# Out:
# X|-|-|-|-|X|-|-|
# ----------------
# -|-|-|X|-|-|-|-|
# ----------------
# -|-|-|-|-|-|-|-|
# ----------------
# -|-|-|-|-|-|X|-|
# ----------------
# -|-|-|-|-|X|-|X|
# ----------------
# -|-|-|X|-|-|-|-|
# ----------------
# -|-|-|-|-|-|-|X|
# ----------------
# -|-|-|-|-|-|-|-|
# ----------------

# %% [markdown]
# ### 10 pts:  Write your code in the cell below to define the "evaFitness" function, which returns the fitness of any given board.
#
# - Noticed that in this case, mutation may generate invalid board, e.g., the board with dupliciate positions.  Think about   [5, 32, 8, 8, 41, 3, 55, 49]
#
# - How to exclude those invalid boards from each generation? One way is to add some penalty to the fitness value of invalid boards.  In that case, any invalid board will have a very high fitness value (remember that our goal is to find the board with least fitness value).    To do that, let's write a function ***checkDuplicate()*** to calculate the number of queen pairs in the same position for any given board.   ***Give each duplicate a high penalty (i.e., multiply by 20, 50) and add the penalty to the fitness value.***
#
# -  evaFitness() returns the total number of duplicate position pair (with penalty) plus the total number of distinct pairs of queens that attack each other.

# %%
#fitness function
def evaFitness(individual):
  conflict = 0

  #print(individual)

  #Check Diagonal
  for i in range(len(individual)):
    for j in range(i+1, len(individual)):
      #Check Diagonal
      if individual[i] != individual[j] and abs(individual[i]//8 - individual[j]//8) == abs(individual[i]%8 - individual[j]%8):
        #print(f'Diagonal conflict {individual[i]},{individual[j]}')
        conflict += 1
      #Check left and right
      if individual[i]//8 == individual[j]//8:
        #print(f'Row conflict {individual[i]},{individual[j]}')
        conflict += 1
      #Check up and down
      if individual[i]%8 == individual[j]%8:
        #print(f'Column conflict {individual[i]},{individual[j]}')
        conflict += 1

  return (checkDuplicate(individual) + conflict,)

# Calculate the number of queen pairs in the same position for any given board
def checkDuplicate(individual):
  dup = 0

  #check if the size of the original list is the same size as the set. (set removes duplicates)
  dup = ( len(individual) - len(set(individual)) ) * 25

  return dup

# %% [markdown]
# ### 5 pts:  Writer your code in the cell below to register "evaluate" function to toolbox

# %%
toolbox.register("evaluate", evaFitness)

# %%
toolbox.register("mate", tools.cxTwoPoint)

toolbox.register("mutate", tools.mutUniformInt, low = 0, up = 63, indpb=0.1)

toolbox.register("select", tools.selTournament, tournsize=3)

# %%
stats = tools.Statistics(key=lambda ind: ind.fitness.values)

# %%
stats.register("avg", np.mean)
stats.register("min", np.min)

# %% [markdown]
# ### 10 pts:  Writer your code in the cell below to create the first generation, the hall of fame, and launch the genetic algorithm: eaSimple().   How many individuals you want to have for each generation and how many generations you want GA to go thourgh for each run?     Vary those two parameters to see the change.

# %%
hof = tools.HallOfFame(maxsize=1)
population, log = algorithms.eaSimple(pop, toolbox, cxpb=0.8, mutpb=0.2, ngen=2000, stats=stats, halloffame=hof, verbose=True)
# Out:
# gen	nevals	avg 	min
# 0  	5     	10.4	8
# 1  	4     	10.2	9
# 2  	4     	9.6 	8
# 3  	1     	8.8 	8
# 4  	4     	8.2 	8
# 5  	5     	8   	8
# 6  	4     	8.2 	6
# 7  	2     	6.8 	6
# 8  	4     	6.2 	6
# 9  	2     	6   	6
# 10 	3     	6.4 	6
# 11 	4     	6   	6
# 12 	0     	6   	6
# 13 	4     	6   	6
# 14 	4     	6   	6
# 15 	3     	5.8 	5
# 16 	3     	6.2 	5
# 17 	3     	5.8 	5
# 18 	2     	5   	5
# 19 	3     	11  	5
# 20 	4     	5.4 	5
# 21 	0     	5   	5
# 22 	5     	5.8 	5
# 23 	4     	5   	5
# 24 	2     	5   	5
# 25 	1     	5.4 	5
# 26 	2     	5   	5
# 27 	5     	10.8	5
# 28 	4     	5   	5
# 29 	4     	5   	5
# 30 	4     	5   	5
# 31 	4     	5.4 	5
# 32 	4     	6   	5
# 33 	4     	5   	5
# 34 	4     	5   	5
# 35 	2     	5   	5
# 36 	4     	5   	5
# 37 	3     	10.2	5
# 38 	4     	5.2 	5
# 39 	2     	5   	5
# 40 	5     	5.2 	5
# 41 	3     	5.2 	5
# 42 	4     	5   	5
# 43 	2     	5   	5
# 44 	4     	5   	5
# 45 	2     	5   	5
# 46 	4     	5   	5
# 47 	3     	5   	5
# 48 	4     	5   	5
# 49 	3     	10.8	5
# 50 	4     	5   	5
# 51 	4     	5.2 	5
# 52 	4     	5   	5
# 53 	4     	5   	5
# 54 	4     	5   	5
# 55 	3     	5.2 	5
# 56 	2     	5   	5
# 57 	4     	5.4 	5
# 58 	4     	5.6 	5
# 59 	2     	5   	5
# 60 	4     	5   	5
# 61 	5     	5.6 	5
# 62 	4     	5   	5
# 63 	4     	5   	5
# 64 	4     	5   	5
# 65 	4     	10.4	5
# 66 	2     	5   	5
# 67 	4     	5   	5
# 68 	3     	5   	5
# 69 	4     	5   	5
# 70 	4     	5.8 	5
# 71 	4     	5   	5
# 72 	4     	5   	5
# 73 	4     	5   	5
# 74 	5     	5   	4
# 75 	4     	4.6 	4
# 76 	2     	4.4 	4
# 77 	2     	4   	4
# 78 	4     	5   	4
# 79 	4     	4.2 	4
# 80 	4     	4   	4
# 81 	4     	4   	4
# 82 	4     	5   	4
# 83 	4     	4   	4
# 84 	4     	4.6 	4
# 85 	4     	4   	4
# 86 	3     	4.6 	4
# 87 	4     	4   	4
# 88 	0     	4   	4
# 89 	5     	4.4 	4
# 90 	0     	4   	4
# 91 	2     	4   	4
# 92 	4     	4   	4
# 93 	3     	4.4 	4
# 94 	2     	4.4 	4
# 95 	2     	4   	4
# 96 	4     	4   	4
# 97 	4     	4   	4
# 98 	4     	4   	4
# 99 	5     	9.8 	4
# 100	3     	5.4 	4
# 101	4     	4.4 	4
# 102	4     	4   	4
# 103	4     	4   	4
# 104	5     	10  	4
# 105	2     	9.6 	4
# 106	3     	9.6 	4
# 107	1     	4   	4
# 108	2     	4   	4
# 109	3     	4   	4
# 110	2     	4   	4
# 111	2     	4.2 	4
# 112	2     	4.6 	4
# 113	3     	4.4 	4
# 114	4     	9.8 	4
# 115	3     	4   	4
# 116	4     	4   	4
# 117	4     	4   	4
# 118	4     	4.4 	4
# 119	5     	3.8 	3
# 120	2     	3.4 	3
# 121	4     	3.2 	3
# 122	2     	3   	3
# 123	4     	3.6 	3
# 124	3     	4   	2
# 125	4     	2.4 	2
# 126	4     	2   	2
# 127	4     	2.2 	2
# 128	2     	2.8 	2
# 129	2     	2   	2
# 130	4     	3.2 	2
# 131	4     	2.4 	2
# 132	3     	2   	2
# 133	0     	2   	2
# 134	4     	2.2 	2
# 135	2     	2.4 	2
# 136	4     	2   	2
# 137	4     	2   	2
# 138	3     	2.8 	2
# 139	4     	2   	2
# 140	4     	2.8 	2
# 141	4     	2.4 	2
# 142	4     	2.6 	2
# 143	4     	2.4 	2
# 144	4     	2.4 	2
# 145	4     	2.8 	2
# 146	4     	2   	2
# 147	3     	2   	2
# 148	4     	7   	2
# 149	4     	3.2 	2
# 150	1     	2   	2
# 151	5     	14  	2
# 152	4     	2   	2
# 153	3     	8.2 	2
# 154	4     	2   	2
# 155	4     	8.2 	2
# 156	4     	2   	2
# 157	4     	2   	2
# 158	4     	2.4 	2
# 159	2     	2   	2
# 160	4     	2   	2
# 161	4     	2   	2
# 162	5     	2.6 	2
# 163	4     	7   	2
# 164	4     	2   	2
# 165	5     	2.8 	2
# 166	4     	2   	2
# 167	4     	7.6 	2
# 168	4     	2.8 	2
# 169	4     	2   	2
# 170	4     	2   	2
# 171	3     	3.4 	2
# 172	4     	2.8 	2
# 173	2     	2   	2
# 174	4     	2   	2
# 175	4     	7.8 	2
# 176	3     	2.4 	2
# 177	4     	7   	2
# 178	4     	2.6 	2
# 179	5     	2.6 	2
# 180	4     	2   	2
# 181	2     	2   	2
# 182	3     	7.4 	2
# 183	4     	2.6 	2
# 184	4     	2   	2
# 185	5     	8.2 	2
# 186	4     	2   	2
# 187	4     	3   	2
# 188	5     	2.2 	2
# 189	5     	2   	2
# 190	2     	2.6 	2
# 191	4     	2.4 	2
# 192	5     	2   	2
# 193	5     	2.8 	2
# 194	4     	2   	2
# 195	4     	2   	2
# 196	2     	2   	2
# 197	4     	2   	2
# 198	4     	2   	2
# 199	4     	2   	2
# 200	2     	2.4 	2
# 201	4     	2   	2
# 202	4     	2.6 	2
# 203	4     	8.4 	2
# 204	4     	2   	2
# 205	4     	2.6 	2
# 206	4     	2   	2
# 207	5     	2.6 	2
# 208	0     	2   	2
# 209	5     	2.4 	2
# 210	4     	2   	2
# 211	5     	2   	2
# 212	2     	2   	2
# 213	4     	2.8 	2
# 214	4     	7.2 	2
# 215	4     	7.6 	2
# 216	4     	2   	2
# 217	4     	2   	2
# 218	4     	2   	2
# 219	5     	2.6 	2
# 220	2     	2   	2
# 221	3     	2   	2
# 222	4     	2   	2
# 223	2     	2   	2
# 224	4     	2.8 	2
# 225	4     	2.2 	2
# 226	3     	2.4 	2
# 227	5     	3   	2
# 228	3     	2   	2
# 229	4     	3.4 	2
# 230	2     	2.2 	2
# 231	3     	2   	2
# 232	4     	2   	2
# 233	3     	2   	2
# 234	4     	2.8 	2
# 235	4     	2   	2
# 236	4     	2   	2
# 237	4     	2   	2
# 238	4     	3.2 	2
# 239	3     	2.6 	2
# 240	2     	2   	2
# 241	4     	2   	2
# 242	4     	2.6 	2
# 243	2     	2   	2
# 244	4     	2   	2
# 245	4     	2   	2
# 246	2     	2   	2
# 247	4     	2   	2
# 248	3     	2.6 	2
# 249	4     	2   	2
# 250	4     	2   	2
# 251	4     	2   	2
# 252	5     	2   	2
# 253	4     	2   	2
# 254	3     	2.4 	2
# 255	2     	2   	2
# 256	4     	2.6 	2
# 257	4     	2   	2
# 258	4     	2   	2
# 259	4     	2   	2
# 260	3     	8.6 	2
# 261	1     	3.2 	2
# 262	2     	7.6 	2
# 263	5     	2.4 	2
# 264	1     	2   	2
# 265	2     	2   	2
# 266	4     	2   	2
# 267	3     	3.8 	2
# 268	2     	2.2 	2
# 269	3     	3   	2
# 270	4     	3   	2
# 271	3     	3   	2
# 272	4     	2.6 	2
# 273	1     	2.8 	2
# 274	1     	2   	2
# 275	4     	2   	2
# 276	2     	2   	2
# 277	4     	2   	2
# 278	4     	2.4 	2
# 279	2     	2.2 	2
# 280	4     	2.8 	2
# 281	5     	3   	2
# 282	5     	7.4 	2
# 283	3     	2.4 	2
# 284	4     	2   	2
# 285	4     	2   	2
# 286	2     	2   	2
# 287	4     	2   	2
# 288	4     	3.2 	2
# 289	3     	2   	2
# 290	4     	1.8 	0
# 291	3     	2   	0
# 292	4     	0.4 	0
# 293	4     	0   	0
# 294	4     	0   	0
# 295	0     	0   	0
# 296	4     	0.6 	0
# 297	4     	0   	0
# 298	4     	0   	0
# 299	4     	0   	0
# 300	4     	1.2 	0
# 301	4     	0.6 	0
# 302	4     	0   	0
# 303	2     	0   	0
# 304	4     	0   	0
# 305	1     	0   	0
# 306	3     	0   	0
# 307	4     	0   	0
# 308	4     	0   	0
# 309	4     	0   	0
# 310	5     	0   	0
# 311	3     	5.4 	0
# 312	4     	0.6 	0
# 313	3     	0.8 	0
# 314	2     	0   	0
# 315	4     	0   	0
# 316	4     	0   	0
# 317	4     	0.4 	0
# 1947	4     	0   	0
# 1948	4     	0   	0
# 1949	2     	0.6 	0
# 1950	2     	0   	0
# 1951	2     	0   	0
# 1952	4     	1.8 	0
# 1953	2     	0.6 	0
# 1954	3     	1.2 	0
# 1955	4     	0.4 	0
# 1956	4     	0   	0
# 1957	2     	0   	0
# 1958	4     	0   	0
# 1959	5     	0   	0
# 1960	4     	0.6 	0
# 1961	3     	0.8 	0
# 1962	4     	1   	0
# 1963	4     	0   	0
# 1964	4     	0   	0
# 1965	4     	1.4 	0
# 1966	4     	6   	0
# 1967	4     	0   	0
# 1968	4     	7   	0
# 1969	4     	0.6 	0
# 1970	2     	0   	0
# 1971	3     	0.4 	0
# 1972	4     	6   	0
# 1973	3     	1.6 	0
# 1974	2     	0.4 	0
# 1975	4     	0   	0
# 1976	4     	0   	0
# 1977	2     	0   	0
# 1978	4     	1.4 	0
# 1979	4     	0   	0
# 1980	5     	1.2 	0
# 1981	2     	0   	0
# 1982	4     	1.8 	0
# 1983	3     	1.2 	0
# 1984	4     	0.6 	0
# 1985	4     	0   	0
# 1986	4     	0   	0
# 1987	4     	6.2 	0
# 1988	5     	0   	0
# 1989	5     	6   	0
# 1990	4     	0.6 	0
# 1991	4     	0   	0
# 1992	4     	0   	0
# 1993	4     	0.6 	0
# 1994	3     	0.6 	0
# 1995	5     	2.2 	0
# 1996	2     	0   	0
# 1997	4     	0   	0
# 1998	4     	0   	0
# 1999	3     	2.4 	0
# 2000	5     	0.8 	0

# %% [markdown]
# ### 5 pts:  Plot the "avg" and "min" for each generation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  

gen, avg, min_ = log.select('gen', 'avg', 'min')
plt.plot(gen, avg, label='average')
plt.plot(gen, min_, label='minimum')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### 5 pts:  Print out the best individual found and its fitness value.  Show the best individual as chessboard

# %%
#best = tools.selBest(population, k=1)
#best_fitness = toolbox.evaluate(best[0])
#print(best[0])
#print(f'Best individual is: {best}, with fitness: {best_fitness}')
#show_grid(best[0])

print(f'Best individual is: {hof[0]}, with fitness: {hof[0].fitness}')
show_grid(hof[0])
# Out:
# Best individual is: [41, 52, 29, 14, 39, 58, 0, 19], with fitness: (0.0,)
# X|-|-|-|-|-|-|-|
# ----------------
# -|-|-|-|-|-|X|-|
# ----------------
# -|-|-|X|-|-|-|-|
# ----------------
# -|-|-|-|-|X|-|-|
# ----------------
# -|-|-|-|-|-|-|X|
# ----------------
# -|X|-|-|-|-|-|-|
# ----------------
# -|-|-|-|X|-|-|-|
# ----------------
# -|-|X|-|-|-|-|-|
# ----------------

# %% [markdown]
# ## Part II: Row-index-based board representation

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)
# Out:
# /usr/local/lib/python3.7/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /usr/local/lib/python3.7/dist-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %% [markdown]
# Each row of the chess row is indexed from 0->7 . we place different queens on different rows initially.  The sequence [ a b c d .... ] means that in $0^{th}$ row, $a^{th}$ column, the queen is present and so on

# %%
toolbox = base.Toolbox()

toolbox.register("attr_int", random.randint, 0, 7)
toolbox.register("individual", tools.initRepeat, creator.Individual,
                 toolbox.attr_int, n=8)

# %%
toolbox.individual()
# Out:
# [4, 4, 0, 3, 2, 6, 4, 1]

# %%
def show_grid(board):
    
    n = [0]*64
    
    for i in range(len(board)):
        n[board[i] + i*8] = 1
      
    
    for i in range(8):
        for j in range(64):
            if j // 8 == i:
                if n[j] == 1:
                    print('X',end="|")
                else:
                    print('-',end="|")
        print()
        print("----------------")

# %%
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

# %%
pop = toolbox.population(n=5)

print(pop[0])
# Out:
# [5, 7, 0, 6, 5, 4, 2, 3]

# %%
show_grid(pop[0])
# Out:
# -|-|-|-|-|X|-|-|
# ----------------
# -|-|-|-|-|-|-|X|
# ----------------
# X|-|-|-|-|-|-|-|
# ----------------
# -|-|-|-|-|-|X|-|
# ----------------
# -|-|-|-|-|X|-|-|
# ----------------
# -|-|-|-|X|-|-|-|
# ----------------
# -|-|X|-|-|-|-|-|
# ----------------
# -|-|-|X|-|-|-|-|
# ----------------

# %% [markdown]
# ### 10 pts:  Write your code in the cell below to define the "evaFitness" function, which return the fitness of any given board
#
# - evaFitness() returns the total number of distinct pairs of queens that attack each other.
#
# - The following are some test cases you may use to verify the correctness of the evaFitness() function:
#
#  * evaFitness([0, 2, 6, 7, 7, 4, 1, 6]) should return (4,)
#
#  * evaFitness([7, 5, 2, 4, 3, 1, 3, 5]) should return (6,)
#
#  * evaFitness([3, 1, 6, 0, 5, 7, 2, 1]) should return (5,)
#
#  * evaFitness([7, 3, 1, 4, 5, 1, 3, 5]) should return (6,)

# %%
#fitness function
def evaFitness(individual):
    conflict = 0
    for i in range(len(individual)):
      for j in range(i+1, len(individual)):
        if not i==j:
          if individual[i]==individual[j]:
            conflict+=1
          if (individual[i]==abs(i-j)+individual[j] or individual[i]==-abs(i-j)+individual[j]):
            conflict+=1

    return (conflict,)

# %% [markdown]
# ### 5 pts:  Writer your code in the cell below to register "evaluate" function to toolbox

# %%
toolbox.register("evaluate", evaFitness)

# %%
toolbox.register("mate", tools.cxTwoPoint)

toolbox.register("mutate", tools.mutUniformInt, low = 0, up = 7, indpb=0.1)

toolbox.register("select", tools.selTournament, tournsize=3)

# %%
stats = tools.Statistics(key=lambda ind: ind.fitness.values)


stats.register("avg", np.mean)
stats.register("min", np.min)

# %% [markdown]
# ### 10 pts:  Writer your code in the cell below to create the first generation, the hall of fame, and launch the genetic algorithm: eaSimple().   How many individuals you want to have for each generation and how many generations you want GA to go thourgh for each run?     Vary those two parameters to see the change.

# %%
hof = tools.HallOfFame(maxsize=1)
population, log = algorithms.eaSimple(pop, toolbox, cxpb=0.5, mutpb=0.2, ngen=100, stats=stats, halloffame=hof, verbose=True)
# Out:
# gen	nevals	avg	min
# 0  	0     	1  	1
# 1  	2     	1.6	1
# 2  	0     	1  	1
# 3  	3     	2.4	1
# 4  	2     	1  	1
# 5  	5     	1.8	1
# 6  	2     	1  	1
# 7  	0     	1  	1
# 8  	0     	1  	1
# 9  	3     	1.8	1
# 10 	3     	1.2	1
# 11 	4     	1  	1
# 12 	4     	1.8	1
# 13 	2     	1.8	1
# 14 	2     	1  	1
# 15 	3     	1  	1
# 16 	4     	1  	1
# 17 	0     	1  	1
# 18 	3     	1.6	1
# 19 	5     	2.6	1
# 20 	4     	1.8	1
# 21 	4     	1  	1
# 22 	3     	1.4	1
# 23 	1     	1.6	1
# 24 	1     	1  	1
# 25 	0     	1  	1
# 26 	0     	1  	1
# 27 	0     	1  	1
# 28 	0     	1  	1
# 29 	3     	1  	1
# 30 	2     	1  	1
# 31 	3     	1  	1
# 32 	0     	1  	1
# 33 	4     	1.4	1
# 34 	3     	3  	1
# 35 	1     	1  	1
# 36 	2     	1  	1
# 37 	4     	1  	1
# 38 	1     	1.4	1
# 39 	3     	1  	1
# 40 	5     	1.4	1
# 41 	3     	2.2	1
# 42 	4     	1.8	1
# 43 	4     	1.4	0
# 44 	2     	0.4	0
# 45 	0     	0.2	0
# 46 	2     	0  	0
# 47 	2     	0  	0
# 48 	3     	1.2	0
# 49 	2     	0  	0
# 50 	1     	0  	0
# 51 	2     	0  	0
# 52 	3     	0.4	0
# 53 	4     	0.4	0
# 54 	2     	0  	0
# 55 	2     	1  	0
# 56 	3     	0.6	0
# 57 	4     	0  	0
# 58 	2     	0  	0
# 59 	4     	0.8	0
# 60 	4     	0  	0
# 61 	4     	0.4	0
# 62 	4     	0  	0
# 63 	5     	0  	0
# 64 	4     	0  	0
# 65 	4     	1.6	0
# 66 	2     	0.6	0
# 67 	4     	0.8	0
# 68 	4     	1  	0
# 69 	4     	0.6	0
# 70 	4     	0  	0
# 71 	0     	0  	0
# 72 	4     	0  	0
# 73 	2     	1.4	0
# 74 	4     	1  	0
# 75 	4     	0  	0
# 76 	3     	0.2	0
# 77 	5     	0.8	0
# 78 	2     	0  	0
# 79 	4     	0.8	0
# 80 	1     	1  	0
# 81 	2     	0  	0
# 82 	3     	0  	0
# 83 	2     	0  	0
# 84 	4     	0.4	0
# 85 	3     	0.6	0
# 86 	2     	0  	0
# 87 	0     	0  	0
# 88 	1     	0.6	0
# 89 	3     	0  	0
# 90 	2     	0  	0
# 91 	2     	0  	0
# 92 	2     	0.6	0
# 93 	3     	0  	0
# 94 	1     	0.6	0
# 95 	1     	0.4	0
# 96 	3     	0.8	0
# 97 	2     	0  	0
# 98 	2     	0  	0
# 99 	2     	0.6	0
# 100	1     	0.4	0

# %% [markdown]
# ### 5 pts:  Plot the "avg" and "min" for each generation

# %%
# Plot the "avg" and "min" for each generation

import matplotlib.pyplot as plt
# %matplotlib inline  

gen, avg, min_ = log.select('gen', 'avg', 'min')
plt.plot(gen, avg, label='average')
plt.plot(gen, min_, label='minimum')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### 5 pts:  Print out the best individual found and its fitness value.  Show the best individual as chessboard

# %%
print(hof[0])
print(f'Fitness: {hof[0].fitness}\n')
show_grid(hof[0])
# Out:
# [5, 2, 6, 1, 7, 4, 0, 3]
# Fitness: (0.0,)
#
# -|-|-|-|-|X|-|-|
# ----------------
# -|-|X|-|-|-|-|-|
# ----------------
# -|-|-|-|-|-|X|-|
# ----------------
# -|X|-|-|-|-|-|-|
# ----------------
# -|-|-|-|-|-|-|X|
# ----------------
# -|-|-|-|X|-|-|-|
# ----------------
# X|-|-|-|-|-|-|-|
# ----------------
# -|-|-|X|-|-|-|-|
# ----------------

# %% [markdown]
# ### Reflection:  Which board representaion is better in terms of ease of coding and final solution quality?   Try different parameter values for mutation and crossover and vary the number of generations and the population size.  Write your findings in the report.
